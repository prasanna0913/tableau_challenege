# %%
import pandas as pd
from functools import reduce
import datetime as dt
import os

# %%
resource_path = './Resources'
only_files = [os.path.join(resource_path, f) for f in os.listdir(resource_path) if os.path.isfile(os.path.join(resource_path, f)) 
              and f.find('.csv') != -1]
dfs = []
for f in only_files:
    df = pd.read_csv(f)
    dfs.append(df)
citibike_combo = pd.concat(dfs)
citibike_combo.head()
citibike_combo.to_csv('citibike_combo_data.csv', sep = ',')
citibike_combo
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2              2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3              2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_combo['Date_time'] = citibike_combo['starttime'].astype('datetime64[ns]')
citibike_combo
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2              2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3              2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
# print(citibike_combo.dtypes)

print(citibike_combo.Date_time.dt.hour.head())
print("\nMinute:")
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Date_time, dtype: int64
#
# Minute:

# %%
citibike_combo['starttime'] = pd.to_datetime(citibike_combo['starttime'], format='%Y-%m-%d %H:%M:%S.%F')
citibike_combo['starttime']
# Out:
# 0       2019-06-01 00:05:55.721
# 1       2019-06-01 00:08:09.092
# 2       2019-06-01 00:13:11.880
# 3       2019-06-01 00:13:30.111
# 4       2019-06-01 00:13:31.852
#                   ...
# 11689   2020-12-31 23:07:44.003
# 11690   2020-12-31 23:18:00.263
# 11691   2020-12-31 23:31:09.462
# 11692   2020-12-31 23:35:45.464
# 11693   2020-12-31 23:48:34.575
# Name: starttime, Length: 468689, dtype: datetime64[ns]

# %%
# citibike_combo[['time']] = pd.DataFrame([ x.split(' ') for x in citibike_combo['starttime'].tolist() ])
# citibike_combo

# %%
# citibike_combo['time'] = citibike_combo['starttime'].str.slice(0,3)
# citibike_combo

# %%
citibike_combo['new_date'] = [d.date() for d in citibike_combo['starttime']]
citibike_combo
# Out:
#        tripduration               starttime                  stoptime  \
# 0               316 2019-06-01 00:05:55.721  2019-06-01 00:11:11.9940
# 1               280 2019-06-01 00:08:09.092  2019-06-01 00:12:50.0730
# 2              2162 2019-06-01 00:13:11.880  2019-06-01 00:49:14.3640
# 3              2184 2019-06-01 00:13:30.111  2019-06-01 00:49:54.2250
# 4               139 2019-06-01 00:13:31.852  2019-06-01 00:15:51.7880
# ...             ...                     ...                       ...
# 11689          1750 2020-12-31 23:07:44.003  2020-12-31 23:36:54.4710
# 11690          1519 2020-12-31 23:18:00.263  2020-12-31 23:43:19.8590
# 11691          1761 2020-12-31 23:31:09.462  2021-01-01 00:00:31.3290
# 11692           637 2020-12-31 23:35:45.464  2020-12-31 23:46:22.7300
# 11693          1607 2020-12-31 23:48:34.575  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
# citibike_combo['new_date'] = [d.date() for d in citibike_combo['starttime']]
# citibike_combo

citibike_combo['new_time'] = [d.time() for d in citibike_combo['starttime']]
citibike_combo
# Out:
#        tripduration               starttime                  stoptime  \
# 0               316 2019-06-01 00:05:55.721  2019-06-01 00:11:11.9940
# 1               280 2019-06-01 00:08:09.092  2019-06-01 00:12:50.0730
# 2              2162 2019-06-01 00:13:11.880  2019-06-01 00:49:14.3640
# 3              2184 2019-06-01 00:13:30.111  2019-06-01 00:49:54.2250
# 4               139 2019-06-01 00:13:31.852  2019-06-01 00:15:51.7880
# ...             ...                     ...                       ...
# 11689          1750 2020-12-31 23:07:44.003  2020-12-31 23:36:54.4710
# 11690          1519 2020-12-31 23:18:00.263  2020-12-31 23:43:19.8590
# 11691          1761 2020-12-31 23:31:09.462  2021-01-01 00:00:31.3290
# 11692           637 2020-12-31 23:35:45.464  2020-12-31 23:46:22.7300
# 11693          1607 2020-12-31 23:48:34.575  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
combined_df = citibike_combo.loc[citibike_combo["gender"] != 0, :]
combined_df
# Out:
#        tripduration               starttime                  stoptime  \
# 0               316 2019-06-01 00:05:55.721  2019-06-01 00:11:11.9940
# 1               280 2019-06-01 00:08:09.092  2019-06-01 00:12:50.0730
# 4               139 2019-06-01 00:13:31.852  2019-06-01 00:15:51.7880
# 5               203 2019-06-01 00:15:43.259  2019-06-01 00:19:06.7450
# 6               671 2019-06-01 00:19:41.579  2019-06-01 00:30:52.6600
# ...             ...                     ...                       ...
# 11682           591 2020-12-31 22:10:54.854  2020-12-31 22:20:46.1760
# 11683           585 2020-12-31 22:11:08.430  2020-12-31 22:20:53.8980
# 11687           653 2020-12-31 22:38:25.468  2020-12-31 22:49:18.5150
# 11691          1761 2020-12-31 23:31:09.462  2021-01-01 00:00:31.3290
# 11693          1607 2020-12-31 23:48:34.575  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
print(combined_df.dtypes)
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                           object
# start station id                    int64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# new_date                           object
# new_time                           object
# time_hour                           int64
# dtype: object

# %%
# Make a reference to the csv file path
csv_path = "Resources/JC-201906-citibike-tripdata.csv"

# Import the csv file as a DataFrame
df_201906 = pd.read_csv(csv_path, encoding="utf-8")
df_201906
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2              2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3              2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
jun19_df = df_201906.loc[df_201906["gender"] != 0, :]
jun19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
june19_bikeid_df = jun19_df["bikeid"].value_counts()
june19_bikeid_df
# Out:
# 29453    155
# 29618    140
# 29572    139
# 29203    136
# 29642    133
#         ...
# 29659      3
# 29573      3
# 29259      2
# 31263      1
# 29757      1
# Name: bikeid, Length: 498, dtype: int64

# %%
# Make a reference to the csv file path
csv_path = "Resources/JC-201907-citibike-tripdata.csv"

# Import the csv file as a DataFrame
df_201907 = pd.read_csv(csv_path, encoding="utf-8")
df_201907
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1               434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2               251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3               636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4               623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
# ...             ...                       ...                       ...
# 43741           673  2019-07-31 23:39:13.1800  2019-07-31 23:50:26.6520
# 43742           161  2019-07-31 23:41:24.1110  2019-07-31 23:44:05.4090
# 43743           310  2019-07-31 23:47:27.3940  2019-07-31 23:52:37.4870
# 43744           137  2019-07-31 23:59:29.9300  2019-08-01 00:01:47.1970
# 43745           463  2019-07-31 23:59:54.9470  2019-08-01 00:07:37.9750
#
#        start station id start station name  start station latitude  \
# ...

# %%
july19_df = df_201907.loc[df_201907["gender"] != 0, :]
july19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1               434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2               251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3               636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4               623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
# ...             ...                       ...                       ...
# 43741           673  2019-07-31 23:39:13.1800  2019-07-31 23:50:26.6520
# 43742           161  2019-07-31 23:41:24.1110  2019-07-31 23:44:05.4090
# 43743           310  2019-07-31 23:47:27.3940  2019-07-31 23:52:37.4870
# 43744           137  2019-07-31 23:59:29.9300  2019-08-01 00:01:47.1970
# 43745           463  2019-07-31 23:59:54.9470  2019-08-01 00:07:37.9750
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Make a reference to the csv file path
csv_path = "Resources/JC-201908-citibike-tripdata.csv"

# Import the csv file as a DataFrame
df_201908 = pd.read_csv(csv_path, encoding="utf-8")
df_201908
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1               172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2               525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3               219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4               262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
# ...             ...                       ...                       ...
# 48706           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# ...

# %%
aug19_df = df_201908.loc[df_201908["gender"] != 0, :]
aug19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1               172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2               525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3               219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4               262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
# ...             ...                       ...                       ...
# 48706           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# ...

# %%
jun19_dfbyduration = jun19_df.loc[jun19_df["tripduration"] < 3600, :]
jun19_dfbyduration
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
# jun19_gb = jun19_df.groupby(["usertype"])
# jun19_gb.count()
# Out:
#             tripduration  starttime  stoptime  start station id  \
# usertype
# Customer            3131       3131      3131              3131
# Subscriber         32962      32962     32962             32962
#
#             start station name  start station latitude  \
# usertype
# Customer                  3131                    3131
# Subscriber               32962                   32962
#
#             start station longitude  end station id  end station name  \
# usertype
# Customer                       3131            3131              3131
# Subscriber                    32962           32962             32962
#
#             end station latitude  end station longitude  bikeid  birth year  \
# usertype
# Customer                    3131                   3131    3131        3131
# Subscriber                 32962                  32962   32962       32962
#
#             gender
# usertype
# Customer      3131
# Subscriber   32962

# %%
jun19_gb = jun19_df.groupby("gender")["tripduration"].max()
jun19_gb
# Out:
# gender
# 1    872985
# 2    914677
# Name: tripduration, dtype: int64

# %%
# combine19_df = pd.merge(df_201906, df_201907,df_201908, on="bikeid")
# combine19_df

# %%
combine_df = pd.concat([jun19_df, july19_df, aug19_df])
combine_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...                       ...                       ...
# 48706           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# ...

# %%
# combine_df['month'] = pd.DatetimeIndex(combine_df['starttime']).month
# combine_df['month']

# print(combine_df['starttime'].dt.time)

# %%
# combine_df.to_csv('Citi_2019_summer_months.csv')

# %%
print(combine_df.dtypes)
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# month                        int64
# dtype: object

# %%
combine_df[['starttime','allele']] = df['V'].str.split('-',expand=True)
combine_df
